# %% [markdown]
# # TextXD'18 hackathon: Analyze Scientific Papers in a Subject
# - read a corpus = WOS
# - clean up
# - text representation: here word stems
# - visualization
#
# by Dani Ushizima and Alex Nascimento

# %%
#Data Wrangling
import pandas
import numpy as np
import os

import gensim #library needed for word2vec

#for visualization
from scipy.spatial.distance import cosine
from sklearn.metrics import pairwise
from sklearn.manifold import MDS, TSNE
import matplotlib.pyplot as plt

# %%
#Visualization parameters
# %pylab inline
# %matplotlib inline
matplotlib.style.use('fivethirtyeight')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#read in all the data, with some cleaning
path ='../data/' #indicate the local path where files are stored
allFiles = os.listdir(path) #save the list of filenames into a variable
print(allFiles)
allFiles = ['New-Dataset.CSV']
# Out:
# ['dani_mask.png', 'Dataset-clean.csv', 'New-Dataset.CSV']

# %%
list_ = []
files_ = []
for file_ in allFiles:
    filename = path+file_ #add the relative path name to the filename
    df = pandas.read_csv(filename, index_col=None, header=0)
    list_.append(df)
data = pandas.concat(list_).reset_index(drop=True)
#view the data
data.head(4)
# Out:
#                                                   TI  \
# 0  Sustainability of construction materials: Elec...
# 1  An automatic and intelligent optimal surface m...
# 2  Life cycle assessment for carbon dioxide emiss...
# 3  Green geopolymeric concrete using grits for ap...
#
#                                                   DE  \
# 0  Electrodialytic technology; Mortars production...
# 1  Tunnel structure; Point cloud; Likelihood meth...
# 2  Life cycle assessment; Climate change; Carbon ...
# 3  Geopolymeric concrete; Biomass fly-ash; Grits;...
#
#                                                   ID  \
# 0             WASTE-WATER; CONCRETE; REMOVAL; SLUDGE
# 1  LASER-SCANNING TECHNOLOGY; FINITE-ELEMENT MODE...
# 2  GREENHOUSE-GAS EMISSIONS; QUANTITATIVE ASSESSM...
# 3               SUSTAINABILITY; TECHNOLOGY; INDUSTRY
#
#                                                   AB    PY
# 0  The reduction of tap water consumption in all ...  2019
# 1  Automatically modeling and intelligently monit...  2019
# 2  Carbon dioxide (CO2) emissions mitigation from...  2019
# 3  This work investigates the production a green ...  2018

# %%
#Number of rows
data.shape
# Out:
# (2311, 5)

# %%
#View the first text
data['AB'][0]
# Out:
# 'The reduction of tap water consumption in all activity sectors, including the building industry, is crucial to the sustainability of water resources. Effluents from wastewater treatment plants have the potential to replace freshwater in the construction sector but they contain a critical mixture of impurities, which hampers their use in mortars production. In this work, the viability of using effluent as an alternative to potable water for the production of mortars, after electrodialytic treatment, was assessed. Electrodialytic technology (ED-T) is a proven technique for decontamination of porous and aqueous matrices. ED-T experiments were conducted with 500 mL of effluent for 6, 12 and 24 h, with a current intensity of 25 mA. The results showed that after ED-T 6 h, the removal efficiencies of critical components were above 85% of their initial concentrations. Mortar properties such as setting time, workability, flexural strength, compressive strength and morphology were obtained for 100% effluent and tap water/effluent mixtures (50:50) with and without ED-T pre-treatment. The mortars with the ED-T treated effluent showed similar initial setting times and workability, higher flexural and compressive strength compared to the mortars reference.'

# %% [markdown]
# # Distiling vocabulary
# - grab all abstracts
# - stemmize and lemmatize
# - frequency analysis

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
#first sentence from wikipedia 
#data = "Concrete, usually Portland cement concrete, is a composite material composed of fine and coarse aggregate bonded together with a fluid cement (cement paste) that hardens over time—most frequently a lime-based cement binder, such as Portland cement, but sometimes with other hydraulic cements, such as a calcium aluminate cement. It is distinguished from other, non-cementitious types of concrete all binding some form of aggregate together, including asphalt concrete with a bitumen binder, which is frequently used for road surfaces, and polymer concretes that use polymers as a binder."
#tokens = word_tokenize(data['AB'][0])
#print(len(tokens))
#print(tokens)
abstracts = data.AB.str.cat(sep=' ')
#' '.join(data['AB'].astype())

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string 
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer


def preprocessing(text):
   
    # tokenize into words
    tokens = [word for sent in sent_tokenize(text) for word in word_tokenize(sent)]
    
    # remove stopwords here might bring you headaches - put it last
    #stop = stopwords.words('english')
    #tokens = [token for token in tokens if token not in stop]
    
    # lower capitalization
    tokens = [word.lower() for word in tokens]

    # steemize
    ps = PorterStemmer()
    tokens = [ps.stem(word) for word in tokens]
    
    # remove stopwords    
    cachedStopWords = set(stopwords.words('english'))
    #subsets
    newStopWords = ['that','usual','include','type','data', 'also']
    exclude = set(string.punctuation) 
    #adding to set
    cachedStopWords = cachedStopWords.union(newStopWords)
    cachedStopWords = cachedStopWords.union(exclude)
    tokens = [w for w in tokens if w not in cachedStopWords]
    
    # remove words less than three letters
    tokens = [word for word in tokens if len(word) >= 3]

    # lemmatize
    lmtzr = WordNetLemmatizer()
    tokens = [lmtzr.lemmatize(word) for word in tokens]
    preprocessed_text= ' '.join(tokens)
    
    return preprocessed_text

# %%
#Better now with stems and lemmas
goodTokens = preprocessing(abstracts)

# %% [markdown]
# ## Simple visualization

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 

text = 'all your base are belong to us all of your base base base'

def generate_wordcloud(text): # optionally add: stopwords=STOPWORDS and change the arg below
    wordcloud = WordCloud(font_path='/Library/Fonts/Verdana.ttf',
                          relative_scaling = 1.0,
                          stopwords = {'use', 'right','one','two','materi','also','process'} # set or space-separated string
                          ).generate(text)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

generate_wordcloud(goodTokens)

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    dani_mask = np.array(Image.open("../data/dani_mask.png"))
    wordcloud = WordCloud(
        font_path='/Library/Fonts/Verdana.ttf',
        background_color='black',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1, # chosen at random by flipping a coin; it was heads
        mask=dani_mask,
        contour_width=3, contour_color='steelblue'
    ).generate(str(data))

    
    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
show_wordcloud(goodTokens)

# %%
from nltk import FreqDist

def graph(f,n=30):
  tokens = word_tokenize(f)
  fd = FreqDist(tokens) 
  plt.figure(figsize=(30, 10))
  plt.rcParams.update({'font.size': 30})  
  plt.xlabel('lexicon', fontsize=20, fontweight='bold')
  plt.ylabel('Counts', fontsize=20, fontweight='bold')
  
  fd.plot(n,cumulative=False)

# %%
graph(goodTokens, 30)

# %%
import os
import re
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
sns.set()

# %%
sns.set(rc={'figure.figsize':(15,8.27)})
sns.countplot(data['PY'], order=data['PY'].value_counts().index);

# %% [markdown]
# # Anything beyond frequency analysis around the lexicon?
#
# 1. **Word embedding**
# 2. topic modeling
# 3. info vis for sumarization

# %%
data['tokens'] = data['AB'].str.split()
model = gensim.models.Word2Vec(data['tokens'].dropna(), size=100, window=5, \
                               min_count=1, sg=1, alpha=0.025, iter=5, batch_words=10000, workers=1)
#check other models at https://radimrehurek.com/gensim/models/word2vec.html

# %%
print('Length of vocabulary:',len(model.wv.vocab))
# Out:
# Length of vocabulary: 33090

# %%
type(data['tokens'][:10])
# Out:
# pandas.core.series.Series

# %%
data.AB.str.lstrip(string.punctuation)
print(data.AB.str.lstrip(string.punctuation))
# Out:
# 0       The reduction of tap water consumption in all ...
# 1       Automatically modeling and intelligently monit...
# 2       Carbon dioxide (CO2) emissions mitigation from...
# 3       This work investigates the production a green ...
# 4       Replacing virgin materials with recycled or su...
# 5       The study describes an attributional life cycl...
# 6       In this work, a Rough Set Analysis-based appro...
# 7       According to the European Cement Association, ...
# 8       Since concrete is the most widely used constru...
# 9       Geopolymer is a cementitious material known fo...
# 10      The concrete production processes including ma...
# 11      This paper evaluates the suitability of stabil...
# 12      According to the National Building Code of Can...
# 13      Industrial wastes and recycled materials are b...
# 14      The strength gain of alkali-activated binders ...
# 15      3D printable construction materials need to be...
# 16      This review paper intends to synthesise the da...
# 17      Mixing crude oil contaminated sand with cement...
# 18      Blast furnace ferronickel slag (BFFS) is a kin...
# 19      The construction industry including infrastruc...
# 20      This research studied the performance of Ordin...
# 21      Concrete is one of the most broadly used const...
# 22      The quartzite minings of AlpinopolisMinas Gera...
# 23      The present paper focuses on developing a stra...
# 24      PurposeMany new opportunities are explored to ...
# 25      The curing of concrete requires high water dem...
# 26      The impact of different hybrid timber building...
# 27      Historically, lightweight foam concrete (LWFC)...
# 28      A large quantity of resources consumed by the ...
# 29      Excess sewage sludge produced in any municipal...
#                               ...
# 2281    This paper addresses the effectiveness of usin...
# 2282    This paper assesses the rock mass characterisa...
# 2283    An earthquake of local magnitude 5.3 (duration...
# 2284    Sludges produced by the treatment of municipal...
# 2285    In 1991, the International Electrotechnical Co...
# 2286    Powder actuated fastening is a quick and cost ...
# 2287    A research program at the Center for By-Produc...
# 2288    Large-scale surface mining and refilling of th...
# 2289    The authors have developed a novel, large diam...
# 2290    An objective of service-life methodology is to...
# 2291    Distribution of wheel loads in concrete bridge...
# 2292    A numerical model is developed for simulating ...
# 2293    The use of reinforced concrete in the United S...
# 2294    The symbolic significance of building material...
# 2295    Coal gasification generates solid waste materi...
# 2296    The Lesotho Highlands Water Project is situate...
# 2297    Crystalline zircon (ZrSiO4) have been discover...
# 2298    Sorption and desorption of tritium (HT) and tr...
# 2299    Steel fiber reinforced concrete is increasingl...
# 2300    The increased requirements for the treatment o...
# 2301    This paper describes a simple and rapid labora...
# 2302    Historical development of the recovery and uti...
# 2303    Simultaneously with the development of new/alt...
# 2304    This study reports on development of a method ...
# 2305    The relationship of various fire conditions to...
# 2306                                                  NaN
# 2307                                                  NaN
# 2308                                                  NaN
# 2309                                                  NaN
# 2310                                                  NaN
# Name: AB, Length: 2311, dtype: object

# %%
#Find the 10 most similar vectors to the given word vector, using cosine distance
model.wv.most_similar('limestone')
# Out:
# [('red', 0.9776163101196289),
#  ('sintered', 0.9673753976821899),
#  ('replacements', 0.9649313688278198),
#  ('pumice', 0.9645620584487915),
#  ('reactive', 0.9625534415245056),
#  ('lime', 0.9621776342391968),
#  ('binder,', 0.9619754552841187),
#  ('oil-palm-boiler', 0.9616963863372803),
#  ('metakaolin', 0.9606481790542603),
#  ('dune', 0.9604861736297607)]

# %%
model.wv.most_similar('environment')
# Out:
# [('pollution', 0.9317535161972046),
#  ('environment,', 0.9215689897537231),
#  ('burden', 0.9211738109588623),
#  ('human', 0.9204119443893433),
#  ('negative', 0.9187787771224976),
#  ('minimize', 0.9113488793373108),
#  ('harmful', 0.9097304344177246),
#  ('cause', 0.907291829586029),
#  ('climate', 0.9066870212554932),
#  ('savings', 0.9064444303512573)]

# %%
model.wv.most_similar('sustainable')
# Out:
# [('environmentally', 0.9251964092254639),
#  ('search', 0.922899067401886),
#  ('friendly', 0.9097700119018555),
#  ('economical', 0.9075288772583008),
#  ('green', 0.9073253870010376),
#  ('eco-friendly', 0.9043868780136108),
#  ('greener', 0.9013631939888),
#  ('disposal.', 0.8942335844039917),
#  ('challenge', 0.8878609538078308),
#  ('economically', 0.8868199586868286)]

# %%
model.wv.most_similar('ash')
# Out:
# [('bottom', 0.8708359003067017),
#  ('coal', 0.864760160446167),
#  ('fly', 0.8639111518859863),
#  ('ash,', 0.8529773354530334),
#  ('ashes', 0.8521843552589417),
#  ('ash.', 0.8446190357208252),
#  ('combustion', 0.844511866569519),
#  ('Fly', 0.8384510278701782),
#  ('(FA)', 0.8320145010948181),
#  ('sludge', 0.8317301869392395)]
