# %%
#import the necessary libraries

#Data Wrangling
import pandas
import numpy as np
import os

import gensim #library needed for word2vec

#for visualization
from scipy.spatial.distance import cosine
from sklearn.metrics import pairwise
from sklearn.manifold import MDS, TSNE
import matplotlib.pyplot as plt

# %%
#Visualization parameters
# %pylab inline
# %matplotlib inline
matplotlib.style.use('fivethirtyeight')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#read in all the data, with some cleaning
path ='../data/' #indicate the local path where files are stored
allFiles = os.listdir(path) #save the list of filenames into a variable
print(allFiles)
# Out:
# ['Dataset-clean.csv', 'New-Dataset.CSV']

# %%
list_ = []
files_ = []
for file_ in allFiles:
    filename = path+file_ #add the relative path name to the filename
    df = pandas.read_csv(filename, index_col=None, header=0)
    list_.append(df)
data = pandas.concat(list_).reset_index(drop=True)
#view the data
data
# Out:
#                                                      TI  \
# 0     Assessing the unpaved shoulder of an airport r...
# 1     Wick drains and piling for Cai Mep container p...
# 2     ITER plasma source and building modelling to p...
# 3     Performance evaluation of steam cured HPC pipe...
# 4                    Beyond the Enclave of Urban Theory
# 5     Atmospheric corrosion study in a harbor locate...
# 6     Renewable energy cooperatives: Facilitating th...
# 7     Properties of Plain Concrete Produced Employin...
# 8     Consolidation Behavior of Fly Ash-Based Geopol...
# 9     Influence of manufactured sand's characteristi...
# 10    From Julius Caesar to Sustainable Composite Ma...
# 11    Development of a particle swarm optimisation m...
# 12    Experimental testing for Zarzis port sediments...
# 13    Application of Simplified Deterioration Diagno...
# 14                 Information function of civil budget
# 15    Galata Port Project in Istanbul: Rehabilitatio...
# 16    Main issues of pile foundation at waterfront d...
# 17    Economic assessment of the alternative energy ...
# 18    SOME CONSIDERATIONS ON BERTH PRODUCTIVITY REFE...
# 19    Comparison of chloride penetration into surfac...
# 20    Land Masking Methods of Sentinel-1 SAR Imagery...
# 21    Effect of Particle Packing and Fly Ash on Perf...
# 22    Mechanical Performance Monitoring for Prestres...
# 23    Quantum simulation of discrete-time Hamiltonia...
# 24    IMPLEMENTATION OF SPATIAL INFORMATION FOR MONI...
# 25    Experimental and nonlinear numerical analysis ...
# 26    Modelling the Behaviour of an Open-ended Coaxi...
# 27    Research on Control Strategy of Wind Power Gen...
# 28    Real-time, Non-instrusive Instrumentation and ...
# 29    Shielding Design for the South Pole nToF Diagn...
# ...                                                 ...
# 2644  Modifications of sulfur polymer cement (SPC) s...
# 2645  ROCK MASS CHARACTERIZATION OF WADI-MUJIB DAM S...
# 2646  OBSERVATIONS FROM THE 12-OCTOBER-1992 DAHSHOUR...
# 2647  CONSTRUCTIVE SLUDGE MANAGEMENT - REUTILIZATION...
# 2648  PROBABILISTIC DERIVATION OF OVERSTRESS FOR OVE...
# 2649  THE NUMERICAL-SIMULATION OF THE IMPACT PHENOME...
# 2650  CONSTRUCTION MATERIALS MADE WITH COAL COMBUSTI...
# 2651  RADIATION EXPOSURE AT THE HIGH BACKGROUND AREA...
# 2652  A LARGE-DIAMETER TRANSMISSION-LINE FOR THE MEA...
# 2653            PREDICTING THE SERVICE LIFE OF CONCRETE
# 2654  LATERAL DISTRIBUTION OF LOADS IN ONE-WAY CONTI...
# 2655  NUMERICAL INVESTIGATION INTO THE INFLUENCE OF ...
# 2656  PLACEMENT-ORIENTED DESIGN AND DELIVERY OF CONC...
# 2657  SYMBOLISM IN BUILDING-MATERIALS - SELF-PRESENT...
# 2658   UTILIZATION OF COAL-GASIFICATION SLAG - OVERVIEW
# 2659  THE GEOLOGY OF THE LESOTHO-HIGHLANDS WATER PRO...
# 2660           HIGH-URANIUM ZIRCON FROM CHERNOBYL LAVAS
# 2661  SORPTION OF TRITIUM AND TRITIATED-WATER ON CON...
# 2662  OPTIMIZATION OF REINFORCED FIBROUS CONCRETE BEAMS
# 2663  REUSE OF WASTE-WATER SLUDGE IN MANUFACTURING N...
# 2664  DETERMINATION OF THERMAL-DIFFUSIVITY OF CONSTR...
# 2665                   UTILIZATION OF STEELMAKING SLAGS
# 2666  FIBER-REINFORCED CONCRETE - A VERSATILE CONSTR...
# 2667  MAPPING AND MEASURING BUILDINGS IN THE CANOPY ...
# 2668  CONCRETE SPALLING - CONTROLLED FIRE TESTS AND ...
# 2669      SULFUR CONCRETE - A NEW CONSTRUCTION MATERIAL
# 2670        SULFUR CONCRETE - NEW CONSTRUCTION MATERIAL
# 2671        SULFUR CONCRETE - NEW CONSTRUCTION MATERIAL
# 2672  POLYMER CONCRETE - POTENTIAL CONSTRUCTION MATE...
# 2673                Concrete as a construction material
#
#                                                      DE  \
# 0     Runway; Port Harcourt; LRS 10; Penetration ind...
# 1       Wick drain; Full-scale tests; Settlement; Piles
# 2     ITER; Tokamak Complex; radiation maps; source ...
# 3     Metakaolin; Pipe piles; Pore structure; Phase ...
# 4     Urban theory; methodology; global urbanism; St...
# 5       atmospheric corrosion; harbor; tropical climate
# 6     Renewable energy; Energy cooperatives; Port of...
# 7     Mixed recycled aggregate; Sea water; Blast fur...
# 8     Consolidation; Dredged mud; Fly ash; Geopolyme...
# 9     Manufactured sand; Particle shape; Gradation; ...
# 10    caisson; ancient ports; breakwater; sustainabi...
# 11    Homogeneity of the mixture; AIR-CNG-hydrogen m...
# 12    geotechnical engineering/ports; docks & harbou...
# 13                                                  NaN
# 14    Information; Access to information; Budget; Ci...
# 15                                                  NaN
# 16                                                  NaN
# 17    Sea Port; Maritime Activity; Alternative Energ...
# 18            berth; productivity; ship turnaround time
# 19    chloride diffusion coefficients; chloride ion ...
# 20    Land Masking; Sentinel-1; Ship Detection; Synt...
# 21    aggregates; anhydrite; compressive strength; f...
# 22    pile-driving monitoring; high-piled wharf; FBG...
# 23                                                  NaN
# 24    spatial information; monitoring of the area ar...
# 25    ANSYS; concrete pressure housing; hollow cylin...
# 26                                                  NaN
# 27    Four-port electromechanical converter; Wind po...
# 28    Component Port Monitor; event-based systems; d...
# 29                                                  NaN
# ...                                                 ...
# 2644                                                NaN
# 2645                                                NaN
# 2646           SEISMIC RISK; DAHSHOUR EARTHQUAKE; EGYPT
# 2647  SEWAGE SLUDGE; BLENDED CEMENT; MORTARS; COMPRE...
# 2648  POLE STRUCTURE; STRUCTURAL OVERSTRESS; CALCULA...
# 2649                                                NaN
# 2650  FLY ASH; BOTTOM ASH; MASONRY; CONCRETE; COMPRE...
# 2651                                                NaN
# 2652                                                NaN
# 2653  ACCELERATED TESTS; CONCRETES; MATHEMATICAL MOD...
# 2654                                                NaN
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                         CHERNOBYL; ZIRCON; URANIUM
# 2661                                                NaN
# 2662  BEAMS (SUPPORTS); FLEXURAL STRENGTH; METAL FIB...
# 2663  SLUDGE; INCINERATION; LIGHTWEIGHT AGGREGATE; C...
# 2664  THERMAL DIFFUSIVITY; CONSTRUCTION MATERIALS; S...
# 2665                                                NaN
# 2666                                                NaN
# 2667                                                NaN
# 2668      FIRE INVESTIGATION; ARSON; SPALLING; GASOLINE
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
# 2673                                                NaN
#
#                                                      ID  \
# 0                                                   NaN
# 1                                                   NaN
# 2                         SHUTDOWN DOSE-RATE; PORT CELL
# 3     SUPPLEMENTARY CEMENTITIOUS MATERIALS; DIFFEREN...
# 4     STUART HALL; CITY; RACE; URBANIZATION; GEOGRAP...
# 5     MILD-STEEL; REINFORCED-CONCRETE; MARINE AEROSO...
# 6                                  CHALLENGES; CLUSTERS
# 7     COMPRESSIVE STRENGTH; STRUCTURAL CONCRETE; HYD...
# 8            MARINE CLAY; SOIL; CEMENT; LIME; SEDIMENTS
# 9     HIGH-STRENGTH CONCRETE; DRYING SHRINKAGE; PART...
# 10    IN-FIELD CONDITIONS; MARINE-ENVIRONMENT; FLY-A...
# 11    SPARK-IGNITION ENGINE; HEAVY-DUTY ENGINE; NATU...
# 12    MARINE DREDGED SEDIMENTS; SCALE EXPERIMENT; CL...
# 13                                             CONCRETE
# 14                                                  NaN
# 15                                                  NaN
# 16                          DREDGED SEDIMENTS; STRENGTH
# 17                                            PV PANELS
# 18                                                  NaN
# 19    SERVICE LIFE PREDICTION; REINFORCED-CONCRETE; ...
# 20                                                  NaN
# 21    CHEMICAL ACTIVATORS; POZZOLANIC REACTION; CEME...
# 22                                        STRAIN SENSOR
# 23            SCATTERING-THEORY; WALKS; PHYSICS; GRAPHS
# 24                PHOTOGRAMMETRY; INTEGRATION; CONCRETE
# 25                                                  NaN
# 26                                             CONCRETE
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2644                                                NaN
# 2645                                                NaN
# 2646                                                NaN
# 2647              CONCRETE; WASTES; ASH; SOLIDIFICATION
# 2648                                                NaN
# 2649                                                NaN
# 2650                                                NaN
# 2651                                                NaN
# 2652                                                NaN
# 2653                                                NaN
# 2654                                                NaN
# 2655                                                NaN
# 2656                                                NaN
# 2657                                                NaN
# 2658                                                NaN
# 2659                                                NaN
# 2660                                                NaN
# 2661                                                NaN
# 2662                                                NaN
# 2663                              ASH; CEMENT; CONCRETE
# 2664                                                NaN
# 2665                                                NaN
# 2666                                                NaN
# 2667                                                NaN
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
# 2673                                                NaN
#
#                                                      AB    PY
# 0     In upgrading the facilities of an Internationa...  2018
# 1     A container terminal, Cai Mep port in the Meko...  2018
# 2     The ITER Tokamak Complex is the civil structur...  2018
# 3     High performance pipe piles are widely used in...  2018
# 4     This essay offers a methodological interventio...  2018
# 5     Atmospheric corrosion level in tropical coasta...  2018
# 6     Renewable energy cooperatives (RECs) are an im...  2018
# 7     The generation of construction and demolition ...  2018
# 8     Ports use soft dredged material for land recla...  2018
# 9     Manufactured sand (MS) is widely considered as...  2018
# 10    The breakwater construction technique using fl...  2018
# 11    Many research works have intended to enhance f...  2018
# 12    This study focused on the feasibility of Tunis...  2018
# 13    For the efficient maintenance of a large numbe...  2018
# 14    Purpose The formation of an information societ...  2018
# 15    The paper describes the design principles, ado...  2018
# 16    Pile foundation is widely used in construction...  2018
# 17    The purpose of this article is to explore spec...  2017
# 18    Productivity at the berth is one from the grou...  2017
# 19    This study investigated the penetration of chl...  2017
# 20    Since land pixels often generate false alarms ...  2017
# 21    A common practice to produce concrete with a l...  2017
# 22    Mechanical performance monitoring of civil inf...  2017
# 23    Recently, a generalization of the standard opt...  2017
# 24    Nowadays, maritime infrastructure is heavily e...  2017
# 25    The paper describes the design and analysis of...  2017
# 26    The study presents the development of a new tw...  2017
# 27    Wind power generation system based on four-por...  2017
# 28    This paper presents an approach for non-instru...  2017
# 29    Neutron time of flight (nToF) detectors are fi...  2017
# ...                                                 ...   ...
# 2644  This paper addresses the effectiveness of usin...  1995
# 2645  This paper assesses the rock mass characterisa...  1994
# 2646  An earthquake of local magnitude 5.3 (duration...  1994
# 2647  Sludges produced by the treatment of municipal...  1994
# 2648  In 1991, the International Electrotechnical Co...  1994
# 2649  Powder actuated fastening is a quick and cost ...  1994
# 2650  A research program at the Center for By-Produc...  1994
# 2651  Large-scale surface mining and refilling of th...  1994
# 2652  The authors have developed a novel, large diam...  1993
# 2653  An objective of service-life methodology is to...  1993
# 2654  Distribution of wheel loads in concrete bridge...  1993
# 2655  A numerical model is developed for simulating ...  1993
# 2656  The use of reinforced concrete in the United S...  1993
# 2657  The symbolic significance of building material...  1993
# 2658  Coal gasification generates solid waste materi...  1993
# 2659  The Lesotho Highlands Water Project is situate...  1993
# 2660  Crystalline zircon (ZrSiO4) have been discover...  1993
# 2661  Sorption and desorption of tritium (HT) and tr...  1992
# 2662  Steel fiber reinforced concrete is increasingl...  1992
# 2663  The increased requirements for the treatment o...  1992
# 2664  This paper describes a simple and rapid labora...  1991
# 2665  Historical development of the recovery and uti...  1991
# 2666  Simultaneously with the development of new/alt...  1991
# 2667  This study reports on development of a method ...  1991
# 2668  The relationship of various fire conditions to...  1991
# 2669                                                NaN  1981
# 2670                                                NaN  1974
# 2671                                                NaN  1974
# 2672                                                NaN  1971
# 2673                                                NaN  1930
#
# [2674 rows x 5 columns]

# %%
#Number of rows
data.shape
# Out:
# (2674, 5)

# %%
#View the first text
data.iloc[0,1]
# Out:
# 'Runway; Port Harcourt; LRS 10; Penetration index; CBR'

# %% [markdown]
# # Example with tiny data
# - data cleaning
# - stop words
# - adding stop words
# - stemmers for reducing inflectional forms

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
 
data = "Concrete, usually Portland cement concrete, is a composite material composed of fine and coarse aggregate bonded together with a fluid cement (cement paste) that hardens over time—most frequently a lime-based cement binder, such as Portland cement, but sometimes with other hydraulic cements, such as a calcium aluminate cement. It is distinguished from other, non-cementitious types of concrete all binding some form of aggregate together, including asphalt concrete with a bitumen binder, which is frequently used for road surfaces, and polymer concretes that use polymers as a binder."
tokens = word_tokenize(data)
print(len(tokens))
print(tokens)
# Out:
# 100
# ['Concrete', ',', 'usually', 'Portland', 'cement', 'concrete', ',', 'is', 'a', 'composite', 'material', 'composed', 'of', 'fine', 'and', 'coarse', 'aggregate', 'bonded', 'together', 'with', 'a', 'fluid', 'cement', '(', 'cement', 'paste', ')', 'that', 'hardens', 'over', 'time—most', 'frequently', 'a', 'lime-based', 'cement', 'binder', ',', 'such', 'as', 'Portland', 'cement', ',', 'but', 'sometimes', 'with', 'other', 'hydraulic', 'cements', ',', 'such', 'as', 'a', 'calcium', 'aluminate', 'cement', '.', 'It', 'is', 'distinguished', 'from', 'other', ',', 'non-cementitious', 'types', 'of', 'concrete', 'all', 'binding', 'some', 'form', 'of', 'aggregate', 'together', ',', 'including', 'asphalt', 'concrete', 'with', 'a', 'bitumen', 'binder', ',', 'which', 'is', 'frequently', 'used', 'for', 'road', 'surfaces', ',', 'and', 'polymer', 'concretes', 'that', 'use', 'polymers', 'as', 'a', 'binder', '.']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string 
from nltk.stem import PorterStemmer

# %%
def removeStopWords(words):
    #select english stopwords
    cachedStopWords = set(stopwords.words('english'))
    #sets
    newStopWords = ['that','all','use']
    exclude = set(string.punctuation) 
    #
    cachedStopWords = cachedStopWords.union(newStopWords)
    cachedStopWords = cachedStopWords.union(exclude)
    new_words = [w for w in words if w not in cachedStopWords]
    return new_words

# %%
newWords = removeStopWords(words)
print(newWords)
# Out:
# ['Concrete', 'usually', 'Portland', 'cement', 'concrete', 'composite', 'material', 'composed', 'fine', 'coarse', 'aggregate', 'bonded', 'together', 'fluid', 'cement', 'cement', 'paste', 'hardens', 'time—most', 'frequently', 'lime-based', 'cement', 'binder', 'Portland', 'cement', 'sometimes', 'hydraulic', 'cements', 'calcium', 'aluminate', 'cement', 'It', 'distinguished', 'non-cementitious', 'types', 'concrete', 'binding', 'form', 'aggregate', 'together', 'including', 'asphalt', 'concrete', 'bitumen', 'binder', 'frequently', 'used', 'road', 'surfaces', 'polymer', 'concretes', 'polymers', 'binder']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string 
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

def preprocessing(text):
   
    # tokenize into words
    tokens = [word for sent in sent_tokenize(text) for word in word_tokenize(sent)]
    
    # remove stopwords here might bring you headaches - put it last
    #stop = stopwords.words('english')
    #tokens = [token for token in tokens if token not in stop]
    
    # remove words less than three letters
    tokens = [word for word in tokens if len(word) >= 3]

    # lower capitalization
    tokens = [word.lower() for word in tokens]

    # steemize
    ps = PorterStemmer()
    tokens = [ps.stem(word) for word in tokens]
    
    # remove stopwords    
    cachedStopWords = set(stopwords.words('english'))
    #subsets
    newStopWords = ['that','usual','include','type']
    exclude = set(string.punctuation) 
    #adding to set
    cachedStopWords = cachedStopWords.union(newStopWords)
    cachedStopWords = cachedStopWords.union(exclude)
    tokens = [w for w in tokens if w not in cachedStopWords]

    # lemmatize
    lmtzr = WordNetLemmatizer()
    tokens = [lmtzr.lemmatize(word) for word in tokens]
    preprocessed_text= ' '.join(tokens)
    
    return preprocessed_text

# %%
#Better now with stems and lemmas
goodTokens = preprocessing(data)

# %% [markdown]
# # Simple visualization

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS 

text = 'all your base are belong to us all of your base base base'

def generate_wordcloud(text): # optionally add: stopwords=STOPWORDS and change the arg below
    wordcloud = WordCloud(font_path='/Library/Fonts/Verdana.ttf',
                          relative_scaling = 1.0,
                          stopwords = {'to', 'of'} # set or space-separated string
                          ).generate(text)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

generate_wordcloud(goodTokens)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    dani_mask = np.array(Image.open(path.join(d, "../data/dani_mask.png")))
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1, # chosen at random by flipping a coin; it was heads
        mask=alice_mask,
        contour_width=3, contour_color='steelblue'
    ).generate(str(data))

    
    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
show_wordcloud(goodTokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f4469396851> in <module>()
#      25     plt.imshow(wordcloud)
#      26 #    plt.show()
# ---> 27 show_wordcloud(goodTokens)
#
# NameError: name 'goodTokens' is not defined
